# %% [markdown]
# Assignment (08/04/2026)
#
# Assignment Name : Image Filter Lab
# Description : Use OpenCV to grayscale, blur, detect edges and show before/after.

# %%
# Cell 1 — Install libraries
# !pip install opencv-python matplotlib numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# DEPRECATION: Loading egg at c:\programdata\anaconda3\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..

# %%
# Cell 2 — Imports & Load Image
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("img.jpg")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

print("Image loaded successfully")
print("Shape:", img.shape)
# Out:
# Image loaded successfully
# Shape: (853, 1280, 3)

# %%
# Cell 3 — Grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

fig, axes = plt.subplots(1, 2, figsize=(10, 4))
axes[0].imshow(img_rgb)
axes[0].set_title("Original")
axes[0].axis("off")
axes[1].imshow(gray, cmap="gray")
axes[1].set_title("Grayscale")
axes[1].axis("off")
plt.suptitle("Step 1 — Grayscale", fontsize=13)
plt.tight_layout()
plt.show()

print("Grayscale shape:", gray.shape)
# Out:
# Grayscale shape: (853, 1280)

# %%
# Cell 4 — Blur
blur_gaussian = cv2.GaussianBlur(img_rgb, (15, 15), 0)
blur_median   = cv2.medianBlur(img_rgb, 15)

fig, axes = plt.subplots(1, 3, figsize=(15, 4))
axes[0].imshow(img_rgb)
axes[0].set_title("Original")
axes[0].axis("off")
axes[1].imshow(blur_gaussian)
axes[1].set_title("Gaussian Blur")
axes[1].axis("off")
axes[2].imshow(blur_median)
axes[2].set_title("Median Blur")
axes[2].axis("off")
plt.suptitle("Step 2 — Blur", fontsize=13)
plt.tight_layout()
plt.show()

# %%
# Cell 5 — Edge Detection
edges_canny    = cv2.Canny(gray, 100, 200)
sobelx         = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=5)
sobely         = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=5)
sobel_combined = cv2.magnitude(sobelx, sobely)
sobel_combined = np.uint8(np.clip(sobel_combined, 0, 255))

fig, axes = plt.subplots(1, 3, figsize=(15, 4))
axes[0].imshow(gray, cmap="gray")
axes[0].set_title("Grayscale Input")
axes[0].axis("off")
axes[1].imshow(edges_canny, cmap="gray")
axes[1].set_title("Canny Edges")
axes[1].axis("off")
axes[2].imshow(sobel_combined, cmap="gray")
axes[2].set_title("Sobel Edges")
axes[2].axis("off")
plt.suptitle("Step 3 — Edge Detection", fontsize=13)
plt.tight_layout()
plt.show()

# %%
# Cell 6 — Full Before / After Summary
fig, axes = plt.subplots(2, 3, figsize=(15, 8))

axes[0][0].imshow(img_rgb)
axes[0][0].set_title("Original (RGB)")
axes[0][0].axis("off")

axes[0][1].imshow(gray, cmap="gray")
axes[0][1].set_title("Grayscale")
axes[0][1].axis("off")

axes[0][2].imshow(blur_gaussian)
axes[0][2].set_title("Gaussian Blur")
axes[0][2].axis("off")

axes[1][0].imshow(blur_median)
axes[1][0].set_title("Median Blur")
axes[1][0].axis("off")

axes[1][1].imshow(edges_canny, cmap="gray")
axes[1][1].set_title("Canny Edges")
axes[1][1].axis("off")

axes[1][2].imshow(sobel_combined, cmap="gray")
axes[1][2].set_title("Sobel Edges")
axes[1][2].axis("off")

plt.suptitle("Image Filter Lab — Before & After", fontsize=15, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
# Cell 7 — Print Summary
print("=" * 40)
print("      IMAGE FILTER LAB — SUMMARY")
print("=" * 40)
print(f"Original shape   : {img.shape}")
print(f"Grayscale shape  : {gray.shape}")
print(f"Gaussian blur    : kernel (15x15), sigma=0")
print(f"Median blur      : kernel size 15")
print(f"Canny edges      : threshold 100–200")
print(f"Sobel edges      : ksize=5, X+Y combined")
print("=" * 40)
# Out:
# ...
#       IMAGE FILTER LAB — SUMMARY
# ...
# Original shape   : (853, 1280, 3)
# Grayscale shape  : (853, 1280)
# Gaussian blur    : kernel (15x15), sigma=0
# Median blur      : kernel size 15
# Canny edges      : threshold 100–200
# Sobel edges      : ksize=5, X+Y combined
# ...
